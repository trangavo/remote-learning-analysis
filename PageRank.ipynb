# %% [markdown]
# # Install and import

# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.5.zip (1.4 MB)
#      |████████████████████████████████| 1.4 MB 3.3 MB/s eta 0:00:01
# Collecting click
#   Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#      |████████████████████████████████| 82 kB 952 kB/s  eta 0:00:01
# Requirement already satisfied: joblib in /opt/venv/lib/python3.7/site-packages (from nltk) (0.16.0)
# Collecting regex
#   Downloading regex-2020.9.27-cp37-cp37m-manylinux2010_x86_64.whl (662 kB)
#      |████████████████████████████████| 662 kB 23.4 MB/s eta 0:00:01
# Collecting tqdm
#   Downloading tqdm-4.50.1-py2.py3-none-any.whl (70 kB)
#      |████████████████████████████████| 70 kB 902 kB/s  eta 0:00:01
# Building wheels for collected packages: nltk
#   Building wheel for nltk (setup.py) ... done
#   Created wheel for nltk: filename=nltk-3.5-py3-none-any.whl size=1434674 sha256=4ba9236d09d883dd1db381d09f762c14c0f2762467563de947f53c97d2ca5185
#   Stored in directory: /home/jovyan/.cache/pip/wheels/45/6c/46/a1865e7ba706b3817f5d1b2ff7ce8996aabdd0d03d47ba0266
# Successfully built nltk
# Installing collected packages: click, regex, tqdm, nltk
# Successfully installed click-7.1.2 nltk-3.5 regex-2020.9.27 tqdm-4.50.1
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
# !pip install networkx
# Out:
# Collecting networkx
#   Downloading networkx-2.5-py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: decorator>=4.3.0 in /opt/venv/lib/python3.7/site-packages (from networkx) (4.4.2)
# Installing collected packages: networkx
# Successfully installed networkx-2.5
# WARNING: You are using pip version 20.2.2; however, version 20.2.3 is available.
# You should consider upgrading via the '/opt/venv/bin/python -m pip install --upgrade pip' command.

# %%
import numpy as np
import pandas as pd
import nltk
nltk.download('punkt')
import re
from nltk.tokenize import sent_tokenize
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = stopwords.words('english')
import networkx as nx
from sklearn.metrics.pairwise import cosine_similarity
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /home/jovyan/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %% [markdown]
# # Load the data

# %%
# !wget http://nlp.stanford.edu/data/glove.6B.zip
# !unzip glove*.zip
# Extract word vectors
word_embeddings = {}

f = open('glove.6B.100d.txt', encoding='utf-8')
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    word_embeddings[word] = coefs
f.close()

# %%
df = pd.read_csv('ug_processed.csv').reset_index(drop=True)

# %%
print(df.shape)
df.head()
# Out:
# (4789, 44)
#    Unnamed: 0  index                                              level  \
# 0           0      4  Undergraduate (studying for associates or bach...
# 1           1      6  Undergraduate (studying for associates or bach...
# 2           2      9  Undergraduate (studying for associates or bach...
# 3           3     13  Undergraduate (studying for associates or bach...
# 4           4     15  Undergraduate (studying for associates or bach...
#
#           country is_online first_survey primary_mode preferred_mode  \
# 0  United Kingdom       Yes           No     recorded       recorded
# 1  United Kingdom       Yes           No         live           live
# 2  United Kingdom       Yes          Yes     recorded           live
# 3  United Kingdom       Yes          Yes         live           live
# 4  Czech Republic       Yes          Yes         live           live
#
#                                             why_mode  \
# 0                  Easier to follow and look back on
# 1   Most similar to normality and provides a routine
# 2                            It is more interactive
# 3  Allows more of a conversation to flow and ques...
# 4                                                NaN
#
#                                       platforms_used  ... active passive  \
# 0  Google Meet, Emailed/Uploaded readings and ass...  ...  False    True
# 1    Zoom, Emailed/Uploaded readings and assignments  ...   True    True
# 2  Zoom, Recorded Lectures/videos from previous y...  ...   True    True
# 3                                        Zoom, Webex  ...   True   False
# 4  Microsoft Teams, Emailed/Uploaded readings and...  ...   True    True
#
#    fully_active  partly_active  outside_passive  outside_interactive  \
# 0         False          False             True                 True
# 1          True          False            False                 True
# 2         False           True            False                 True
# 3          True          False            False                 True
# 4          True          False             True                 True
#
#    outside_assignments  is_online_short num_methods  num_techniques
# 0                False              Yes           1               2
# 1                False              Yes           2               1
# 2                 True              Yes           0               3
# 3                False              Yes           1               1
# 4                 True              Yes           2               4
#
# [5 rows x 44 columns]

# %%
why_mode = df['why_mode'].dropna().to_list()
why_preference = df['why_preference'].dropna().to_list()
remote_changes = df['remote_changes'].dropna().to_list()
prior_changes = df['prior_changes'].dropna().to_list()

remote_changes_sampled = remote_changes[:500]

# %% [markdown]
# # Build the model

# %% [markdown]
# ## Text processing

# %%
# tokenize sentences
def sentence_tokenize(data):
    sentences = []
    for s in data:
        # break articles into sentences
        sentences.append(sent_tokenize(str(s)))
    sentences = [y for x in sentences for y in x] # flatten list
    return sentences

# %%
# remove punctuations, numbers and special characters, lowercase
def lower_abc(data):
    clean_sentences = pd.Series(data).str.replace('[^a-zA-Z]', ' ')
    clean_sentences = [s.lower() for s in clean_sentences]
    return clean_sentences

# %%
# function to remove stopwords
def remove_stopwords(sen):
    sen_new = ' '.join([i for i in sen if i not in stop_words])
    return sen_new

# %%
def removed_joined(data):
    return [remove_stopwords(r.split()) for r in data]

# %% [markdown]
# ## Vectorization

# %%
# create vectors for sentences
# average dim of words
def vectorization(data):
    sentence_vectors = []
    for i in data:
        if len(i) != 0:
            v = sum([word_embeddings.get(w, np.zeros((100,))) \
                    for w in i.split()])/(len(i.split())+0.001)
        else:
            v = np.zeros((100,))
        sentence_vectors.append(v)
    return sentence_vectors

# %% [markdown]
# ## Apply PageRank algorithm

# %%
# similarity matrix
def sim_matrix(sentence_vectors, m):
    sim_mat = np.zeros([m, m])
    for i in range(m):
        for j in range(m):
            if i != j:
                sim_mat[i][j] = cosine_similarity(sentence_vectors[i].reshape(1,100), \
                                              sentence_vectors[j].reshape(1,100))[0,0]
    return sim_mat

# %%
# apply pagerank algorithm
def pagerank(sentences, sim_mat):
    top_content = []
    nx_graph = nx.from_numpy_array(sim_mat)
    scores = nx.pagerank(nx_graph)
    ranked_sentences = sorted(((scores[i],s) for i, s in enumerate(sentences)), reverse=True)
    return ranked_sentences

# %%
# summary extraction
def final(original_sentences):
    tokenized = sentence_tokenize(original_sentences)
    clean_sent = lower_abc(tokenized)
    clean_sent = removed_joined(clean_sent)
    vectorized = vectorization(clean_sent)
    sim_mat = sim_matrix(vectorized, len(tokenized))
    return pagerank(tokenized, sim_mat)

# %% [markdown]
# # Run the model

# %%
final(remote_changes_sampled)
# Out:
# [(0.0018175271869698795,
#   'Have more time because it is not the same  if you are not used to online classes and sometimes it is difficult to understand some concepts that are really practical (and because of online classes you are not able to actually do so you can understand them better)'),
#  (0.0018166444491600502,
#   'Make the class sizes smaller on zoom lecturers so it’s easier to ask questions and have some sort of way to test our learning as we go rather than just having one big essay at the end to write'),
#  (0.0018155555705278187,
#   'Make it more engaging, it can be quite a one way learning system, more discussion'),
#  (0.0018145564617524084,
#   'Would be good if all online classes are made to be more interactive and allow for more thinking (instead of just absorbing of content).'),
#  (0.0018142436881921824,
#   'To have online lectures like we normally would do in person as we haven’t had any video call lectures on sites such as zoom at all and I am a third year student who has finished a degree on their own pretty much.'),
#  (0.0018137133074200176,
#   'I would not try to replace biochemistry labs with online assingments (although they\'re still the best element of the whole e-learning), but rather opt for making it possible to organise them in the labs (we\'re actually starting "normal" anatomy practicals next week, so it\'d be possible).'),
#  (0.0018128895421391073,
#   "I would prefer to have more lecture style videos and live meetings as I feel it's a better way of engaging with students"),
#  (0.0018111974636547076,
#   'I would want tutorials (small group) teaching as they have note even tried to hold these sessions online.'),
#  (0.00181038102917751,
#   'More progress checks, to check this style of work is working for us and we aren’t just doing less work than we normally would be if learning wasn’t online.'),
#  (0.0018097638397376885,
#   'I think my lecturers should use zoom meetings as these are more interactive and would make me feel more involved in university life.'),
#  (0.0018077399998614673,
#   'More would be live lectures as I engage with them better and it gives me more structure and I find them more useful in terms of understanding the content'),
#  (0.0018063192074340144,
#   'It would be great if every teacher would use the same methodes/puts the same amount of effort into online classes.'),
#  (0.001805852305699332,
#   'Record new content instead of using old lectures from previous years because information is not always relevant/in depth enough to function as out only source of teaching'),
#  (0.0018051272416631944,
#   "Some of our teachers just upload material for us to read and discuss in forums with the class, they don't really give us much feedback for our exercises."),
#  (0.0018050375409771693,
#   'There’s only so much the uni can do online and I feel like mine did a pretty good job and tried to keep it as similar as possible to actual, in-person classes.'),
#  (0.0018043627629411873,
#   'have them be more interactive in some way or a better use of the time as most of them werent really relevant'),
#  (0.001803773456048876,
#   'I would have more pre-lecture preparation added, because sometimes you turn up to a lecture and have issues understanding some of it but if this material had been posted in advance, you could have done further reading and research in order to fully engage with the material in the lecture'),
#  (0.0018021774364119325,
#   'Could hold live lectures and seminars at specific times in order to stick to a routine and boost motivation'),
#  (0.001801170373401389,
#   'I would like to have more live lectures for the structure of my days and to make it feel less distant'),
#  (0.0018005156956785195,
#   'Add live tutorial sessions for those subjects which don’t already do this as it gives the class the opportunity to ask questions and interact with each other.'),
#  (0.0017992589040880381,
#   'Often in regular classes I turn to the person next to me to ask a question, so I wish there was some way of doing that.'),
#  (0.0017990218425285385,
#   'Instead of voiceovers over the presentation, I would prefer watching the Professor drawing diagrams, a forum to ask live questions and maybe assignments to Go over at the end of the week.'),
#  (0.0017978720898305677,
#   'The teachers skills using the platform, a good 1/3rd time goes just to make sure audio is working or not'),
#  (0.0017966347899016338,
#   'Probably I would add more interactive activities, or even add he modality of writing essays in order to make the courses more engaging'),
#  (0.001796311728448498,
#   'As well it feels more personal, especially when students and professors can have discussions during this lecture (questions, etc) to feel as though it is in-person.'),
#  (0.0017959417748174054,
#   'I would want to have more little tests throughout lectures to know how much i understand'),
#  (0.0017958885566965702,
#   "Induvidialised 'office hours' or something simmilar is needed for our programming lectures, as each student is working on a different project."),
#  (0.0017943230238866002,
#   'no live lectures bc i do not pay attention in those.. i work better when i can work when i actually want to'),
#  (0.0017942652301988495,
#   'I would make them into more interactice ones, i mean i would include the students more by taking them in because our lecturers do it really in a monological way'),
#  (0.0017933469016970548,
#   'The classes should be recorded even when they are live lectures because not all students have the same possibilities, wifi problems, not computers for everyone in the house...'),
#  (0.0017926103736262728,
#   'I want all of the classes to be live, and I want more student participation throughout, the way it normally would have been in college.'),
#  (0.00179225182169815,
#   'I would have live teaching and the requirement of engagement in the learning, so I would actually do the work.'),
#  (0.0017919360266114568,
#   'If these groups are randomised every time, you still stay in personal contact with lots of people just as you would in regular class'),
#  (0.0017914014867041442,
#   "Honestly, I'd like other students to engage more, maybe add camera view and unmute, so that the discussions feel more natural"),
#  (0.0017912767990367513,
#   "They assured us they're not but we can't review our answers after we choose them and there's less time because we have an open book (this doesn't happen in all my classes but still)."),
#  (0.0017912659358042822,
#   'Classes are too big, sometimes 80 of us on one call and it can crash the system/lag, makes it harder for individual questions to be seen or for interaction as there are so many of us'),
#  (0.0017911970931018327, 'i would make the classes more interesting'),
#  (0.0017904519555784967,
#   'Begin able to see the other course mates as part of social interaction'),
#  (0.0017900957408523237,
#   'They’re not used to online teaching and it has been very hard for them, so it’s kind of hard for me as well to comprehend the subject.'),
#  (0.0017882216854039263,
#   'More group work to make the classes more engaging so that I am able to learn more'),
#  (0.0017875135744385492,
#   'I would like my professors to interact more with the students in order to make the online classes more engaging.'),
#  (0.0017872228482233151,
#   'I would teach them live + have more assignments as we go through our program so that I can be more aware of what I actually understand'),
#  (0.001786880633002159,
#   'my classes were usually on moodle, so no interaction whatsoever, i would change that and make it a mixture of both learning by myself and a teacher talking over a document'),
#  (0.0017865929336450172,
#   'All instructors should use only one platform on college level, rather than different for each subject.'),
#  (0.0017859850039295732,
#   'They have us watch videos in which professors explain Histological pictures and then attend the usual 2-hour histology class meaning I have to spend almost twice as much time on it.'),
#  (0.0017859425044256174,
#   "I wouldn't change anything, I think it works really well, although my internet connectivity does affect my ability to contribute sometimes"),
#  (0.0017858102028628516,
#   'It is difficult to concentrate fully in the online setting with the distraction of being at home/family members as compared to in a classroom setting.'),
#  (0.0017856952393205104,
#   'I would have preferred more live zoom classes so it could represent the classes we had in person better.'),
#  (0.001785557627352682,
#   'Lectures released live so we get the opportunity to ask questions during the lecture rather than having to use a discussion board afterwards and maybe wait a few days for a reply'),
#  (0.0017854886814097299,
#   'More interactive and more little assignments because now it is even harder to test if you understand the course'),
#  (0.0017852323829041445,
#   'I would like to be able to interact a little bit more, but there isn’t a huge difference with in-person classes.'),
#  (0.0017848746083776437,
#   'I wish some profesors would put more effort in their online classes, since some of them just gave us class material and expect us to do it on our own without any explaination.'),
#  (0.0017846368564734857,
#   "My professors don't even do live classes, so it is very difficult to reach them and get questions answered."),
#  (0.0017842669376621283,
#   'I would change my tutorials to make them live as currently, the lecturers set a question sheet and email the answers.'),
#  (0.001783971160921975,
#   'They need to be more effective like actually uploading the material they are teaching because they go by them like in the speed of light'),
#  (0.0017835789037024938,
#   'However, I feel so uncomfortable being on video chat with 40 or so students that I don’t know well.'),
#  (0.0017833285638853024,
#   'I would give the lecture recordings earlier so students are able to watch all of them before the professors do a live online Q&A.'),
#  (0.0017831466508493648,
#   'Almost always several people start speaking up/sending questions and due to this flood, instructors often lose the overview and skip questions.'),
#  (0.0017823838553934362,
#   'Allowing the students to turn off their cameras and mics if not asked a question because it helps me feel less stressed'),
#  (0.0017817539316506373,
#   'Pre recorded lectures would be really helpful as live ones via zoom often becomes sidetracked'),
#  (0.0017814182095252898,
#   "the way that professors are not aware about the fact that lots of hours of classes, with them talking nonstop it's really unhelpful to the learning progress"),
#  (0.001781245883577864,
#   'Have the PowerPoint prior to the class so that I could make notes and prepare questions that may help a discussion'),
#  (0.001780940052086364,
#   "More online/live lecturers because I feel like we've been thrown in the deep end without alot of information."),
#  (0.0017807806816919967,
#   'I don’t like to post on discussion forums so I might get rid of that but I find reading them useful'),
#  (0.0017807336610927837,
#   'I would made them live lectures, because I think it’s more interactive and engaging'),
#  (0.0017801490599379476,
#   'I feel like the tutors aren’t putting as much effort in as they would in a physical class'),
#  (0.0017800322116778462,
#   'I honestly wish none of the curriculum was cut out- there was so much to learn and it only halted further learning and understanding of upcoming material.'),
#  (0.0017799941984403987,
#   'Make it more interactive cause most of my online classes are lectures and I get distracted easily'),
#  (0.001779297476547941,
#   "I'm getting emails every day with more materials which is making it hard to plan my work."),
#  (0.0017785984236869206,
#   'A better method of writing on a shared space like blackboard like (would make studying maths easier)'),
#  (0.001778595001983865,
#   'Also instructors shouldn’t relay on one method only, but use all (or as many as they can) methods listed in question 5 bc everyone has they own way which is best for them, and it should be available to them in this hard times...'),
#  (0.001778573972741938,
#   'Actually do lectures and discussions live instead of charging us fees for nothing in some departments'),
#  (0.0017782552621091806,
#   'I would maybe try to make some videos shorter (for example, not one big video of 2 hours but 4 little ones) or.'),
#  (0.0017782503466295158,
#   'something to get students more involved during class, because we get easily distracted when you only listen without having any interaction'),
#  (0.0017781233613126373,
#   'I would prefer it if there were regular check up/ mock tests because it is hard to know whether you have understood the new material.'),
#  (0.0017777511264243557,
#   'It would be better if there were less people in one class if the professor wants us to participate often'),
#  (0.001777534340421401,
#   'Another reason is that we also use Bongo but this does not work well for everyone in our class'),
#  (0.0017774867904728144,
#   'Also, maybe the teachers should actually make people turn the cameras on and ask more questions.'),
#  (0.0017770765887128227,
#   'make the lectures be taught from this year and relate the content to the world today'),
#  (0.001776883717730028,
#   'It would make me want to study more for the upcoming lessons as you would get tested in them.'),
#  (0.0017766256098463316,
#   'Make them all live lectures (recorded and posted after for different time zones) because this helps me stay engaged and stay up to date with lectures.'),
#  (0.0017762876920769568,
#   'My engagement during an online lecture is SIGNIFICANTLY lower than during in-person lectures, so I think online courses need to be structured differently.'),
#  (0.0017757944869765618,
#   'I’m studying pharmacy and it’s a really tough and intense course, but we were mostly left to our own devices when Covid happened, and it made it very difficult to keep up with the course work.'),
#  (0.0017753870100749086,
#   'I wish there were more constant and small testing instead of one big exam (but my college did this before being online too)'),
#  (0.0017750004519852779,
#   'The amount of extra work needed because our school doesnt do live learning like on Zoom.'),
#  (0.0017749575167015823,
#   "How long they last, because we have the same time we used to have for classes, but with much more work load, such as tests and it feels like we don't have time for school, family time, friend time and also personal time."),
#  (0.0017733985302635419,
#   'Not just use presentations with lecturer talking through them all the time, maybe use other methods of learning or involvement.'),
#  (0.0017732523612964156,
#   'We did not have all of our courses in an online form (some were only based on self-studying) so I would add those missing.'),
#  (0.0017724867254486295,
#   'Some of the videos are way too detailed and long as well (not relevant for exams or anything)'),
#  (0.0017722823227059854,
#   "I would love to have some live content and also surveys so you don't just sit and not engage."),
#  (0.0017712165788279519,
#   'More group activities within the class time to apply the discussion in a more practical sense'),
#  (0.0017712028520494505,
#   'More small quizes or something a little more interactive so that you would be more engaged during classes on zoom.'),
#  (0.0017711954617417452,
#   'Furthermore I have two 3 hour classes and that is a lot of time to stare at a screen so would like shorter more frequent classes.'),
#  (0.0017710913012367617,
#   'More zoom calls so I would actually do the work rather than just posting the lectures on blackboard'),
#  (0.0017710135828407818,
#   'More group discussion because I find that when you are discussing in a whole group discussion it is better to pick out ideas with others first.'),
#  (0.0017707953161173952,
#   'I would make it more organised and following a common mould for all courses so I don’t lose my attention'),
#  (0.001770263449125473, '1000-1500 words instead of 2000), or set less work.'),
#  (0.0017698871832172438,
#   'I would want there to be a way for us to ask questions directly (during class time) Instead of having to email'),
#  (0.0017698146001198295,
#   'I would like to be more involved, so I’d like lessons via Zoom for example, where there is human interaction.'),
#  (0.0017694866770397548,
#   'I would like to have online tutorial groups as this would be very helpful'),
#  (0.0017693490169650454,
#   'I have mostly recorded lectures but I think it would be more beneficial to have zoom classes that are more like a seminar.'),
#  (0.0017690256798901577,
#   'Also knowing what the exact subject is going to be so I can prepare better'),
#  (0.0017690169031643753,
#   'I wish my professors would make more time during class to answer questions.'),
#  (0.001768818077676748,
#   'Also, if I wasn’t at home, I feel like it would be easier to focus'),
#  (0.0017684723221666105,
#   'Turn the chat box function off on collaborate ultra on canvas so that the teacher wasn’t constantly interrupted mid thought by students questions and forcing students to turn cameras on and use their microphones'),
#  (0.0017673422742388325,
#   'I feel like the online learning should have a lock mode where you can’t go to different websites while a lecture is happening.'),
#  (0.0017672621843188572,
#   "It really took me a lot of time to get more comfortable talking, but I still don't like talking in online classes."),
#  (0.0017671397343945088,
#   'Make sure all lecturers release recorded sessions as some haven’t really provided much'),
#  (0.0017670227115914724,
#   'No I think they’re doing their best but I don’t like online classes as such'),
#  (0.0017669902006478392,
#   'Make the teaching smaller and more interactive, as our course is quite large'),
#  (0.0017666537087875172,
#   'the quality of panopto is pretty low - better video quality would make it a lot easier to see words and equations on the boards'),
#  (0.0017656256516431863,
#   'I wouldn’t change anything i don’t like them and prefer in person lectures'),
#  (0.0017652207413682813,
#   'I would ask for actual clases or a live Q&A session instead of just online material (mostly PDFs and homework)'),
#  (0.00176477325311287,
#   'More interaction, that would help me to stay motivated but also to just learn from my teachers'),
#  (0.0017644001121757216,
#   'Less hours, and less work, we have many subjects to read for'),
#  (0.0017640406366810591,
#   'Make it accessible to every student, it usually was very awkward'),
#  (0.0017639280398786396,
#   'And I would like for the classes to be more interactive other than just the teacher talking to the students.'),
#  (0.001763658245709322,
#   "I would make use of more material, as in most of them it's only the professor talking"),
#  (0.0017633420417973327,
#   'It would be much better if every lecturer was engaged.'),
#  (0.001763249384946657,
#   'I would love to have more pre work and work with that in class.'),
#  (0.0017630520187518436,
#   'Also some of them are not really good with comunication with students and how they should reach out.'),
#  (0.0017626053010090961,
#   'More 1:1 opportunities with lecturers as it can often be daunting to ask questions/comment in front of everyone in a live meeting e.g don’t want to interrupt'),
#  (0.0017624120350752026,
#   "It worked well in person with tutors moving around the room but online it really hasn't worked"),
#  (0.0017622767651903704,
#   'Some of my teachers teach without any power point or document for the students to follow along.'),
#  (0.0017611567996562156,
#   'I found it hard to learn the content at times due to the fact it wasn’t face to face learning.'),
#  (0.0017608258120345036,
#   'As an arts student, it felt impossible to fully get the education I need from in studio assignments and rehearsals'),
#  (0.0017602234083792011,
#   'I would like more structure i think, as giving us assignments and material with the promise of no feedback or marks is not motivating at all!'),
#  (0.0017602024643093215,
#   'Make some extra content eg videos to support learning in topics that are harder than others'),
#  (0.0017600873297472666,
#   'This way I would be more engaged and motivated to do my university work as I would have structure to my days.'),
#  (0.0017600499687861991,
#   'I would like to introduce the mandatory attendance backe in group project, so every body would need to take part in the meetings.'),
#  (0.0017593264043834153,
#   'Having people required to go, however I know that’s not possible for everyone.'),
#  (0.0017592600647039292,
#   'More live classes with possibilities to interact would be nice.'),
#  (0.0017583912316725314,
#   'Discussion forums are not good enough, I’d much prefer online meetings etc because we can engage more'),
#  (0.001758050196246694,
#   'I would like to have a chance to be in different small group with a different people not just with one all class.'),
#  (0.0017572536428213097,
#   'More opportunity for interaction with professors as it would be easier to understand if we had more opportunities to go over issues'),
#  (0.0017567455746888838,
#   'Chaos is inevitable when up to 500 students are in the same live class, especially when it comes to asking questions.'),
#  (0.0017567352704900441,
#   'I would add a feature that keeps the students concentrated on the lecture'),
#  (0.001756271360887502,
#   'It’s hard to jump in online and ask a question when you’re in a lecture with 100+ people'),
#  (0.0017561686909726782,
#   'As many of the assessment methods have changed, I feel this makes it harder to predict the structure of, and style of questions that an exam might contain'),
#  (0.001755670596865472,
#   "More standardization-we're a small school so there's no official page for online school, it's all whatever professors feel like doing."),
#  (0.0017554947531232701,
#   'For my philosophy course we only get pre-recorded lectures without any further discussion.'),
#  (0.0017545262334361829,
#   'I tried to keep the same hours as usual but the teachers wouldn’t have always uploaded the work.'),
#  (0.0017543019915298393,
#   'I would make them shorter and use them only for interaction/q&a purposes so that we can do research/reading/grammar etc individually'),
#  (0.0017536809668820279,
#   'I would make it compulsory for everyone to switch on their cameras during video classes.'),
#  (0.0017534761835617182,
#   'We need a weekly end goal, something to work towards so I stay motivated and on track'),
#  (0.0017533368431399343,
#   'Most of our content was taught via power points and discussion board chats and I didn’t find it helpful or engaging'),
#  (0.0017532217895891997,
#   'Nothing to change per say, I do miss the face-to-face contact of a workshop and the discussions that take place in the moment'),
#  (0.0017530389267431804,
#   'Probably make them more interactive and engaging, currently it’s very easy to be passive and it’s difficult to absorb any information'),
#  (0.0017526180969723647,
#   'I would not have to spend so much time on self-studying.'),
#  (0.0017505864402952407,
#   'Moreover, I would like more one on one office hours with my tutors.'),
#  (0.0017505806247986144, 'More live discussion to keep students engaged.'),
#  (0.001750452838866877, "I'd want a way for students to be less distracted"),
#  (0.0017489548845790463,
#   'Some tutors already did this, but I would appreciate if tutors understood the difficult circumstances and therefore asked for shorter essays (e.g.'),
#  (0.0017486970348510363,
#   'I prefer live lectures, since the students can actively ask questions.'),
#  (0.0017485752367423205,
#   "Sometimes it's difficult to attend normal lecture times from home (students with children etc.)"),
#  (0.0017475435019981918,
#   'Make sure the technology works because often it fails'),
#  (0.0017474716034361023,
#   'If we have questions we have to upload them to a place where every student sees them as well as the professor.'),
#  (0.0017454670494829725,
#   'Maybe incorporate more live lectures in in the morning since that would forced me to get up in the morning.'),
#  (0.0017454508292369074,
#   'But I am studying in International House (place where I am taking English class) we have changed our classes to online ones.'),
#  (0.001744976160239149,
#   'Some of my presentations take very long, because of the big group of people.'),
#  (0.0017447103485094127,
#   'Because i find it difficult to engage without physical resources to work on.'),
#  (0.001744631180353978,
#   'The environment is less than ideal and I feel like lecturers need to do more in terms of assisting our learning!'),
#  (0.0017445272662042675,
#   'Get more participation from other students so there is more discussion and everyone understands better'),
#  (0.0017444210017223323,
#   'I think more use of breakout rooms is nice to engage in discussions.'),
#  (0.0017436921385588016,
#   "I would want recorded lectures to be shorter because I'm struggling to watch a 90 or more minutes long video while only listening."),
#  (0.0017423730402571684,
#   'More Live classes, less pressure on our assignments'),
#  (0.0017421648203037067,
#   'I would love to have a live lesson or even a prerecorded one.'),
#  (0.0017408804060446456,
#   'Since we are not at uni anymore classes could concentrate rather than having gaps in between'),
#  (0.001739882277284366,
#   'The way they do exams because I don’t think they give us enough time to do them right'),
#  (0.0017392896404068625,
#   'I would break the big group up in smaller groups more often to discuss and brainstorm and to return with a more active attitude.'),
#  (0.0017386052038987172,
#   'Emulating in person class doesn’t work for all, make presentations more engaging etc.'),
#  (0.0017379036240548836,
#   'Have more live content and I am able to ask more questions or ask the staff to re-phrase the content.'),
#  (0.0017376578824872492,
#   'Would have the lectures record rather than only having the available slides'),
#  (0.0017372851651383048,
#   'Remove the ability for students to not allow the use of their microphone because only a couple of the same students actually respond via microphone everyone else refuses to speak'),
#  (0.0017371147905188423,
#   'More interaction with all students rather than listening to the lecturer talk for the full duration'),
#  (0.0017368898468256202,
#   'Maybe have interactive lectures not pre recorded so then they are closer to the original learning experience'),
#  (0.0017368565031931726, 'I would rather they were live'),
#  (0.0017366811705194008,
#   'All recorded lectures with an optional Q&A for those that need help or want more depth'),
#  (0.001736549664845351,
#   'Designated slots for each person to speak, to avoid the difficulties in managing who speaks when and who gets priority if two people start speaking at the same time'),
#  (0.0017357843870075176,
#   'Timetabled them more spaced out rather than back to back lectures - allows you more time to get up away from your laptop'),
#  (0.0017349801008261308,
#   'My teachers’ way of explaining through online classes.'),
#  (0.0017349475861070474, 'And also make these groups a bit bigger (3-4).'),
#  (0.0017348544701056492,
#   'More activities or discussions that are outside the traditional question and answer model'),
#  (0.0017346621739238264,
#   'I would record the lectures instead of just sending the presentation.'),
#  (0.001733360552317676,
#   'Maybe I would make them more interactive because I often find myself getting distracted with my phone and noone can see me, which makes it easier for me to get distracted.'),
#  (0.001733257966564943,
#   'The professions to put more effort and mix up the techniques they use, were all new to this but they are putting not a lot of effort in'),
#  (0.0017332563923129225, 'More live lectures as I feel I would engage more'),
#  (0.0017330483557947965,
#   'Not have an automatic pass to second year and have assignments converted to an online format so we are motivated to learn the content and get our moneys worth.'),
#  (0.0017322429736888367,
#   'I would like for them to be recorded at all times to help with weak internet connections'),
#  (0.0017314405499725925,
#   'I feel less comfortable asking questions so don’t enjoy it when the lectures turn on camera and microphone and ask questions'),
#  (0.0017300944104070462,
#   'To make it more interactive as it helps me to take in the material'),
#  (0.001729923525418491,
#   'I would have made live classes regularly with a stable timetable, both explaining the contents and resolving doubts.'),
#  (0.0017297832875219094,
#   "I understand there is not much else to do but I don't feel useless tasks are a way to spend this time."),
#  (0.0017290620104558443,
#   'I would prefer some of my classes to be more interactive.'),
#  (0.0017284516999853613,
#   'Some courses could benefit from more organized information on their pages, but other than that, I have no complaints'),
#  (0.0017281628593047381,
#   'A better platform for online classes that is more engaging then the existing ones.'),
#  (0.001727914437957716,
#   'I’d make them more interactive, involving the students more.'),
#  (0.0017278806228778496,
#   "I've had to wait for replies on numerous accounts for way too long,making me demotivated"),
#  (0.0017278221654890087,
#   'I wish there was a better way of reading how people backchannel!'),
#  (0.0017277259503315388,
#   'I would have more smaller group activities and less pre-recorded lectures'),
#  (0.0017276650075060908,
#   'Honestly, for a history degree it might have been better to have more lectures/reading materials.'),
#  (0.001727509072503308,
#   'Live drawing of diagrams - if they used a stylus with their phone using an app to show it on the screen, it would add so much to my learning.'),
#  (0.0017273532855545525, 'The way the presentations work'),
#  (0.0017269669471269944,
#   'I wish there was an opportunity to get to know the other students better.'),
#  (0.0017268795925000113,
#   "I would change the amount of live resources we're given."),
#  (0.0017265608499171324,
#   'I would allow for some kind of partial credit on more quantitative subjects instead of multiple choice.'),
#  (0.0017264108618008697,
#   'I would like more activities like mini-quizzes or something that wold make the lection more engaging'),
#  (0.0017263661659136845,
#   'Some of the assignments are designed to be discussed/ done at uni and not at home and they have not yet adapted them to the current situation, so adapting these assignments and some professors do not upload assignments on time'),
#  (0.0017262717200856176,
#   'Some professors switched from simple exams to 40 pages long portfolios, which is inhumane considering that everyone changed their requirements to essays.'),
#  (0.0017257972530369365,
#   'Giving it was my final term of my last year at university it would have been good to of had more than 1 online class!'),
#  (0.0017256835913091546,
#   'Having either recorded lectures or zoom seminars would be good.'),
#  (0.001725300467580726,
#   'Perhaps a variety of types of learning used so including a PowerPoint and maybe a video.'),
#  (0.0017251596648921647,
#   "Nothing, I didn't have that many online classes because the assessments at my university were cancelled."),
#  (0.001724472793094015, 'make more smaller assignments instead of one final'),
#  (0.0017244108789448652,
#   'My teachers haven’t been doing much lectures, I only had one or two and felt very lost.'),
#  (0.00172295052186167,
#   'I would like to have live lectures so that it resembles normal university, pre-corona times'),
#  (0.0017229248664501848,
#   'Pre-structure live student question Q&A session, so that questions are submitted before and discussed live.'),
#  (0.0017228593670208982,
#   'My professors have really piled on the work, and I would appreciate some more flexibility during these times.'),
#  (0.001722082892111302,
#   'To teach live and to use breakout rooms for discussion.'),
#  (0.0017218239826974765,
#   'I would like them to be more interactive so I don’t get as easily distracted.'),
#  (0.0017212290154023742,
#   'Online classes would be more effective with smaller groups in more interactive classes.'),
#  (0.001720554445422408,
#   'The way the content of the lecture was presented to us.'),
#  (0.001720283883770406,
#   'Would probably be better if student showed their faces,\nMore likely to pay attention.'),
#  (0.0017201036206220966,
#   'I also think that some lecturers have become less helpful/responsive when replying to emails because you don’t see them face to face'),
#  (0.0017200518250657874,
#   'The organisation, sometimes it’s really unclear what video goes with what week'),
#  (0.0017195598082851691,
#   'Actually have live lessons as it has become such a waste of tuition todo nothing for an entire term.'),
#  (0.0017193272865092305,
#   'More live sessions as classmates motivate each other and can see things in different lights'),
#  (0.001719176338531864,
#   'Have them happen live rather than recorded so there’s more motivation to attend'),
#  (0.0017189637073774784,
#   'I would have smaller groups and students could be assigned to them according their time zones.'),
#  (0.0017185006148432212,
#   'A lot of the times, he just reads front the slides rather than explaining them in a way for us to understand'),
#  (0.0017183937017047927,
#   'Make them more interactive and have a forum where we can do smaller group works as well.'),
#  (0.001718304056145685,
#   'only one of my teachers used zoom, the others assigned readings or documentaries or essays and gave up on teaching us.'),
#  (0.0017180674649711328,
#   'perhaps a group with my professors and my seminar/tutor group where we can post any queries or ask questions about reading or assignments and received a faster response'),
#  (0.0017179797015526776,
#   'The education method my uni uses (design based education) is usually really effective but just doesn’t work online.'),
#  (0.0017178839077952957,
#   'More interaction rather than just our lecturer talking all the time so that its more of a social experience'),
#  (0.0017161378402225302, 'Lectures would be live instead of pre-recorded'),
#  (0.0017159853772118693,
#   'Some do regular, full classes in Zoom and others send barely an email.'),
#  (0.0017150503574258652,
#   'Have either live lectures or video recordings to give more detail than the PowerPoints alone.'),
#  (0.0017149069341761978,
#   'I would lovr for us to have smaller groups, so that we could actually all interact and partecipate'),
#  (0.0017147273567986792,
#   'Make it more engaging as it’s easy to lose focus or cheat ie translation in language classes'),
#  (0.0017142142425580471, 'However I do not enjoy online classes.'),
#  (0.0017141350907120911, 'I would make them more interactive'),
#  (0.001714135090712091, 'would make it more interactive'),
#  (0.0017134852586222565,
#   'I love my course but not having any has made me less engaged in my course.'),
#  (0.001713399504016246, 'Make it easier for verbal discussion to happen.'),
#  (0.0017130150672397698,
#   'I’d find new methodologies to make online classes more participative'),
#  (0.0017130062336412019,
#   "I feel the problem are not the classes themselves but the environment: it is easier to get distracted and unmotivated when you're alone on you're room"),
#  (0.0017120663839393932,
#   'I would like more engaging materials rather than worksheets'),
#  (0.0017115592073673781,
#   'I would ask to put the material on a live zoom/video chat.'),
#  (0.0017110726316816038,
#   'Making them more interactive to actually use the knowlege you are learning'),
#  (0.0017101994221693276,
#   'If anything, the professors didn’t keep to a normal schedule.'),
#  (0.0017101861799225027,
#   'I was used to having small group discussions at uni, so to have no personal contact at all was a complete shock'),
#  (0.0017099396120224567,
#   "Make them more accessible ie if you don't want to answer a question you can email later"),
#  (0.0017093579540529375,
#   'mmm i’d perhaps make it compulsory for everyone to have their videos turned on?'),
#  (0.0017090708424591374, 'I would make them more engaging'),
#  (0.0017084030390136274, 'I would like them to be more interactive.'),
#  (0.0017082736254914917,
#   'using webcams as it would force me to engage and not go on my phone'),
#  (0.0017069849182994017,
#   "I'd love to have some kind of live contact with our professors"),
#  (0.0017068062761325044,
#   'I would change the frontal approach to make it more dynamic, interesting and engaging.'),
#  (0.0017066800963888185,
#   'Have more small quizzes or things that keep you interested, so you do not get distracted as easily.'),
#  (0.0017056770794955415, 'People should actually come on camera'),
#  (0.0017044409714558595,
#   'More personal contact, so zoom meetings or something like that.'),
#  (0.0017043667185833735,
#   'Class length - currently too long\nPractical class content- too simiĺar in each ballet class we do very similar floor Barre practice \nPace of lesson- is incredibly slow in some lectures'),
#  (0.0017042268400553997,
#   'How my practical lessons are made, we cant do lots of stuff because we need multiple items for those things.'),
#  (0.0017040245169282436, 'Would make discussions anonymous'),
#  (0.0017033506471228856, 'Making students more engaged in the material'),
#  (0.0017031167530779292,
#   'At least one weekly live lecture with the whole class'),
#  (0.001702878949518951,
#   'Have the lecturers change the content more to adapt to online rather than using pre existing PowerPoints etc.'),
#  (0.0017019568592977227,
#   'Have a live time for lectures as well as it recorded and uploaded so it feels more real'),
#  (0.0017018356387028632,
#   'I hope there is a way that I can see everyone on the screen because otherwise I’m always afraid that someone is going to say something and I might speak over him/her.'),
#  (0.0017013852941621412,
#   'I would try to make them more efficient and personal.'),
#  (0.0017008577994477036,
#   'More content, compared to my in-person classes pre-covid the amount of content we are receiving is much less'),
#  (0.0017002960103172573,
#   'So I wouldn’t change anything except the course lecturers and professors sticking to their deadline better'),
#  (0.001700197843478447,
#   'We need a platform designed for education not for business meetings'),
#  (0.001700076486493931,
#   'For lectures I would prefer they are just pre-recorded.'),
#  (0.0016993998309427535,
#   'Minor detail but makes you feel less lonely, more accountable and I feel like it benefits the professor too!'),
#  (0.0016993258470788283,
#   'I would definitely submit explanatory videos for the topics and straightforward, well-explained instructions for the assignments.'),
#  (0.0016992536717039108,
#   'So we are on camera (less likely to get distracted & more focused)'),
#  (0.0016991019961232218,
#   'Record them for people that live in different time zones.'),
#  (0.0016989060756594475, 'I can’t really see how to make them less awkward'),
#  (0.0016986021469951817,
#   'Reducing the amount of live classes because they don’t help me at all'),
#  (0.001698496630966612, "Recorded one's are much better."),
#  (0.0016984432004215429,
#   'if classes are going to change assessment and pass rates should change too.'),
#  (0.00169808869726811, 'I would prefer to have live classes and workshops.'),
#  (0.001697728340903554,
#   'With more regular quizzes in the lecture to make sure you have been listening'),
#  (0.0016974505738005553, 'Better way of conducting seminars'),
#  (0.0016967894015693223,
#   'To avoid issues with connection and timing which often prevents all questions from being addressed by both the lecturer and students'),
#  (0.0016962977944723226,
#   'more small group discussions, to learn more from my peers'),
#  (0.001695919463392462, 'Actually receive online classes'),
#  (0.001695808834585311,
#   'I could only communicate by e-mails, which sometimes took time.'),
#  (0.0016957549694127715,
#   'Everything because I want to feel engaged in classes and reading out Loud (what my prof is doing) I can do it on my own'),
#  (0.0016954871086101362,
#   'More small group teaching where you can discuss things with a lecturer and your peers.'),
#  (0.001694646731084755, 'Using one certain platform.'),
#  (0.0016946174317972915,
#   'Professors engaging class during online lectures instead of staring at a screen for 1+ hours'),
#  (0.0016945907175497318,
#   'Live zoom calls so material can be explained  and discussed'),
#  (0.0016938238381578527,
#   'Try to add more practical work in as I am on a practical course'),
#  (0.0016935634060001134,
#   'More "random" interactions, ie not strictly about the material, just small talk before/after class'),
#  (0.0016908002892376073,
#   'teachers are doing less and we are expected to do more, it just doesn’t seem fair.'),
#  (0.0016888051875385691,
#   'Also, I would have kept the original number of exams and projecte instead of basing all the grade on one final exam.'),
#  (0.001688140067830633,
#   'More interactive and live a lecture or seminar would usually be.'),
#  (0.0016875953779084225,
#   'Especially because they do it in in-person teaching'),
#  (0.0016870844555370898,
#   'Content taught in other way as it is not the same to in person classes when professor are reading off them'),
#  (0.001687047294996958,
#   'Turn-on would probably keep me sit down instead of distracted'),
#  (0.0016868401630279366,
#   'Not just lecture capture, things made this year by lecturers aswell'),
#  (0.0016865673905509452,
#   'I’d incorporate more activities to prevent the students from getting distracted.'),
#  (0.0016852512463754131,
#   "Mandatory to show faces during video classes... i'm shy and it feels oddly invasive showing the class my room."),
#  (0.0016850545199416178,
#   'Make them compulsory in order to increase my motivation, however this is difficult considering the circumstances'),
#  (0.0016843871569767622, 'To teach material and test students frequently.'),
#  (0.001684208263848951,
#   "The same format for every module so I don't have to get use to multiple methods and platforms for learning."),
#  (0.0016825898411371913,
#   'More small groups/breakouts/other ways of shifting activities so that the monotony of listening to the prof talk is broken up.'),
#  (0.0016823742668962483, 'Maybe more time for questions'),
#  (0.0016822973353950977,
#   'Make them all live, so that I’m not just reading slides online'),
#  (0.001681281388386903,
#   "In this situation it's very difficult to be productive all day and they just increase our work."),
#  (0.001678904193328678,
#   'It’s sometimes hard to navigate awkward silences or multiple people talking at the same time.'),
#  (0.0016788607268033908,
#   'More discussions och på att with other people who are taking the course, because it can feel quite lonely when you dont actually meet them in class.'),
#  (0.0016779048019783139,
#   'For them to be more regular so I feel I am still attending university and have more of a schedule.'),
#  (0.0016777189851309544,
#   'Actually explaining topics instead of reading a presentation.'),
#  (0.0016777095779313903, 'More facilities/times to ask questions'),
#  (0.001676468997799102, 'Still maintain some sort of schedule or routine'),
#  (0.001675895500090977,
#   'Right now only the loud people who are conformable speaking talk during lectures, while most people just stay quiet.'),
#  (0.0016758264503017111, 'I would like there to be more structure.'),
#  (0.0016756738131235352, 'I wish it would be easier for everyone to engage.'),
#  (0.0016751300134198346,
#   'Have lectures recorded live this year instead of using them from last year'),
#  (0.0016743260002135617,
#   'Currently there are a lot of students in a lecture so we can only communicate through the chat attached to the video streaming'),
#  (0.0016736888570808722,
#   'I think because it was set up in my university in such a rush, it needed to be organised and more technologically advanced'),
#  (0.001672148082390936, 'Make voices more clear and less lagging'),
#  (0.0016718186492221312,
#   'Live Zoom classes rather than re-recorded lectures for more engagement'),
#  (0.0016715577983896018,
#   "I don't feel comfortable doing that so I'd rather ask the questions anonymously or just from the professor"),
#  (0.0016710420096188643,
#   'More provided material directly from instructors - some modules have not provided much active content'),
#  (0.0016705797208135965,
#   'I would prefer to have extra support than usual, such as supplementary notes'),
#  (0.0016702530987080528,
#   'That way everybody would feel engaged and motivated.'),
#  (0.0016693524744842763,
#   'They should be able to use and use all digital tools that chosen platform provide (ex.'),
#  (0.001668481417848719, 'Nothing really, just not online'),
#  (0.0016668208874110874, 'They aren’t long enough or regularly scheduled'),
#  (0.0016666861457629077, 'Teachers knowing how the technology works'),
#  (0.0016659537933680273,
#   'Less assignments to do after classes, the amount of it is right now 3x bigger than in “typica” classes'),
#  (0.0016647027647356443, 'We would have more live group interactions'),
#  (0.001664647623912669,
#   "I study at a polytechnic so some of our more practical classes can't convert that well to online."),
#  (0.0016643949752806863, 'Add more interactive time with professors'),
#  (0.0016633312303780718,
#   'Afternoon only - young people don’t want morning lectures'),
#  (0.0016597166952120076,
#   "It feels as though we are being set pointless tasks so that the uni can't be accused of doing nothing."),
#  (0.0016590114013756657,
#   'I like recorded lectures but they can sometimes feel very impersonal.'),
#  (0.0016587878060105054, 'Don’t make them live'),
#  (0.001658308824538729,
#   'My university cancelled all teaching for the last two weeks of second term and since third term is exam season I feel I have missed out a lot of contact time since lockdown.'),
#  (0.0016581819526042777, 'Be able to have more interaction between students.'),
#  (0.001657804235490477, 'I really wish they were live and interactive.'),
#  (0.0016577051999425287, 'Time to ask more questions'),
#  (0.0016559437436278858,
#   'Make sure that more happens live and not just uploaded'),
#  (0.0016558076420065389,
#   'More frequent - they don’t stick to the usual time table - the hours are massively reduced'),
#  (0.001655060311327479,
#   'Some lecturers just posted the lectures from the previous years which feels less applicable'),
#  (0.0016550200453980674,
#   'Create a more interactive experience to enjoy in discussions'),
#  (0.0016542300148319946,
#   'So that would need to be adjusted because right now it’s frustrating'),
#  (0.0016537738963425027,
#   'Having live content to promote a structure to learning'),
#  (0.0016535628932328433,
#   'Have more videos to watch in our own time and have more breaks.'),
#  (0.0016533177212801522, 'Addition of small group discussion.'),
#  (0.0016529113588574442, 'I would change that.'),
#  (0.001650965993529462,
#   'They just talk about the subject in theory, do not ask any questions and leave as they please.'),
#  (0.0016493189914603375,
#   'More online classes and shorter assignments (at my school we have around 100 pages to read and sum up in 5 classes)'),
#  (0.0016493116340422292, 'I would have more interactive sessions.'),
#  (0.0016492245949384832,
#   'Make them more interactive and force participation to engage more'),
#  (0.001649093966460302,
#   'Live lectures as oppose to recorded lectures - allows for more content engagement'),
#  (0.0016477016321817264,
#   'More diversified methods of teaching would greatly improve our learning in my opinion.'),
#  (0.0016465607646589098,
#   'Uploading pdfs without any explanation should not be considered a way of teaching'),
#  (0.0016445043611519336, 'The way exams are given.'),
#  (0.0016438045126292372,
#   'More direct interaction and opportunities to ask specific questions to lecturers.'),
#  (0.0016429840202888421,
#   'Lecturers be more informed on how to use online media to deliver lectures.'),
#  (0.0016423649986054378, 'Nothing to change!'),
#  (0.0016421735745207697, 'just try to have some live video calls :)'),
#  (0.001642032043854821, 'The way teachers engage with the students.'),
#  (0.0016417973265886133,
#   'More empathy for students that dont have the means to have online classes'),
#  (0.0016413172032657389, 'Better technology so cameras are able to be on'),
#  (0.0016400440574523983,
#   'More visual methods e.g powerpoints during an online class instead of just a lecturer speaking.'),
#  (0.0016397342111150652, 'I just wish all of my courses were conducted live.'),
# ...
#  (0.001632142749515637,
#   'Teachers being more consistent and providing good alternatives that are substantial'),
#  (0.0016292404821443565,
#   'To have more time for discussion/have more meetings per week.'),
#  (0.001628810839352776,
#   'Having lecture presentations or class recordings of zoom meeting available after the course meeting.'),
#  (0.001628693092829399, 'More of a live chat, more of an opportunity to ask'),
#  (0.0016262909324350745,
#   'The professores should be more compreensive and try harder to help the students.'),
#  (0.0016259697035745171,
#   'More support toward the students, more understanding of their mental health and more lectures'),
#  (0.0016248279858544475,
#   'More engagement or more assessments to help consolidate learning better.'),
#  (0.0016247807509066302,
#   'More anonymous engagement so that more people can discuss and contribute.'),
#  (0.0016244493446866556,
#   'To be honest, I would have appreciated more help from the instructors'),
#  (0.0016236193375401317, 'They could be more interactive'),
#  (0.00162294624308031, 'Online quizzes whilst chatting would be useful'),
#  (0.0016229150262838795,
#   "It's harder to absorb information without a lecturer explaining and addressing queries"),
#  (0.0016196661344102445,
#   'How easily it is to get distracted and not pay attention.'),
#  (0.0016189221643414726, 'The amount of work.'),
#  (0.0016189221643414721, 'The amount of work'),
#  (0.0016187341230672382,
#   "More interactive classes it is hard to just listen for so long when I'm so comfy on my sofa"),
#  (0.0016184559401732506, 'Use one or two platforms.'),
#  (0.0016180217584641835,
#   'This would help with engagement and fighting distraction.'),
#  (0.0016178955820014696, 'I’d like the lessons to be more engaging'),
#  (0.0016177549764203544,
#   'Filming of the lectures face whilst talking through the slides as nobody is on camera feels very isolated.'),
#  (0.0016177266668672278, 'I wouldn’t change anything.'),
#  (0.0016170800213958557, 'Using more than one platform can be confusing.'),
#  (0.001616883695041656,
#   'Quicker platform to ask questions with fast responses'),
#  (0.0016162559649842436, 'So none of the content was explained properly.'),
#  (0.0016159345359919484, "I would'nt change nothing."),
#  (0.0016149396962127972, 'Maybe more face to face learning'),
#  (0.0016142665033748807, 'To have more live discussions or group activities'),
#  (0.0016133000117763872, 'My uni doesn’t do much so do more online classes'),
#  (0.0016129489783855697,
#   'We only have language courses with 10-20 people, all the other courses 40+ ones.'),
#  (0.0016126878510336468,
#   'More interactive with use if questions or quiz to test knowledge'),
#  (0.001611984854527278, 'The strange part is talking with a screen.'),
#  (0.0016119335257547484, 'Make it more engaging'),
#  (0.0016099752585498777, 'Live discussion'),
#  (0.0016095473691961906, 'I don’t think they are ‘designed’.'),
#  (0.0016088980582749685,
#   'I do a languages degree and the lack of oral practice is really hindering my progress'),
#  (0.0016078392388024895,
#   'different methods of engagement: doing kahoots, games, etc'),
#  (0.0016072194729687928,
#   'I always feel sorry for lecturers when nobody has their camera on or nobody is contributing to the discussion.'),
#  (0.0016052618750108589, 'The exams are now going to be harder I think.'),
#  (0.0016037414331758805,
#   'Having discussion forums so students can ask questions which are then addressed in the recorded lectures'),
#  (0.0016033102130414674, 'so the instructions aren’t always very clear'),
#  (0.0016027624742266159,
#   'A zoom q and a for big assignments to answer questions and explain verbally in depth'),
#  (0.0016026107524857642, 'Time of day'),
#  (0.0016009223025046518, 'More small group discussion'),
#  (0.0016005232795869052,
#   'More interactive/live sessions, less recorded lectures'),
#  (0.001600106058538225,
#   'Ensure the recorded lectures are upload before or at the time of the lecture scheduled'),
#  (0.001600017627525951,
#   'Chance to anonymously answer questions/gain immediate feedback'),
#  (0.001599218490423061,
#   'Live teaching instead of recorded lectures (PowerPoint with voice over)'),
#  (0.0015986928923199886, "I think that'd help with distractions."),
#  (0.0015980708007550838,
#   'Sometimes it’s a little confusing when there’s gonna be classes, assignments etc.'),
#  (0.0015979430943352886, 'make them more interactive'),
#  (0.0015979430943352886, 'Make them be more interactive'),
#  (0.0015979430943352882, 'Make them more interactive.'),
#  (0.0015945000683649413, 'Better communication with the professors'),
#  (0.0015912462437671024, 'More structured, better prepared'),
#  (0.0015910557619717245, 'More opportunity to engage and ask questions'),
#  (0.0015891875104416394,
#   'More applications and examples, actual exercise resolutions, not just "finish this by yourselves"'),
#  (0.0015887663536988308,
#   'For it to be a bit more organised with smaller group sessions'),
#  (0.0015876597669897072,
#   'All live lecture with more structure and engagement'),
#  (0.0015852908371002637, 'Option for live study on zoom etc'),
#  (0.0015852048102178793,
#   'More than just uploaded lecture materials, have known office hours for lecturers'),
#  (0.0015851415317087916, 'Wish teachers were more interactive.'),
#  (0.0015840564048170116, 'Have more online class discussion.'),
#  (0.001583796085090193,
#   'For no apparent reason, my college decided to rush through the left over syllabus for the remainder of the semester.'),
#  (0.001583394137912905, 'Lack of practical experience'),
#  (0.0015833486779486066,
#   'I wish student participation was mandatory, and valuable in your califications.'),
#  (0.0015829309357991042, 'One live weekly update'),
#  (0.0015829162237507828,
#   'More recorded lectures (but not for all classes, though)'),
#  (0.0015811892312781652, 'Better platforms used'),
#  (0.001580471065070646, 'Different lecturers have used different methods.'),
#  (0.0015729521291430102,
#   'A lot of our key primary sources became inaccessible because they weren’t/can’t be digitised (copyright issues ugh)'),
#  (0.0015707072147410671,
#   "more interaction with theprofessors that don't record videos or meetings"),
#  (0.0015699421582681086,
#   'More support from my professors - because of online, there is an apparent disconnect between students and professors'),
#  (0.0015687559082975153,
#   'Perhaps a video of lecturer talking while interacting with slides'),
#  (0.0015661399890648266,
#   'unofficial custom among students at my university is to have them switched off'),
#  (0.0015657930729735458, 'More live discussions'),
#  (0.001561753306096095,
#   'How frequently they occur - they don’t occur as often as I think they should'),
#  (0.0015593099171986586, 'Not having to show my face on video.'),
#  (0.0015576957506963978, 'Live classes which are interactive'),
#  (0.0015570782338959037, 'Because I do not feel as an expert in education.'),
#  (0.0015561721131912326, 'To use more interactive media.'),
#  (0.0015557143898460189, 'In some cases, socratic style may be helpful.'),
#  (0.0015520896176962863,
#   'I missed those during my course, moreover, these led to unnecessary confusion.'),
#  (0.0015485414293234577, 'More live debate'),
#  (0.0015481983909878272, 'More live classes'),
#  (0.0015473009936172466, 'More time per individual'),
#  (0.0015462239648482666,
#   'Literally, the rest of the semester I was spacing out and kept getting distracted.'),
#  (0.00154492725947678, 'The way our lecturer gives the lectures.'),
#  (0.0015422115505682606, 'Its annoying to use 10 platforms for 10 courses.'),
#  (0.0015400826788450378,
#   'I’d have access to materials I need slime a workshop and laptop'),
#  (0.001538790003712356, 'Make them shorter'),
#  (0.0015387900037123552, "I'd make them shorter"),
#  (0.001538399320300281, 'More engaging and not left to our own devices'),
#  (0.001538298809381342, 'Move to live lectures than prerecorded'),
#  (0.0015374936901860047, 'Up to date lecture recordings - not last years'),
#  (0.001536556893996088, 'I would record them'),
#  (0.0015361676282382097, 'Nothing really.'),
#  (0.001533665669258948, 'More practice exam materials provided.'),
#  (0.0015327705011896815, 'Reduce the amount of students per Zoom class.'),
#  (0.0015303063099861597, 'the quality of taught sessions are not the same.'),
#  (0.0015273927436047145, 'Not sure'),
#  (0.0015273927436047139, 'Not sure'),
#  (0.0015273927436047139, "I'm not sure"),
#  (0.0015254665779364566, 'More focus'),
#  (0.001523436660487513, 'Their lack if knowledge with technology.'),
#  (0.0015228126092361434, 'i don’t know'),
#  (0.0015228126092361432, "I don't know"),
#  (0.0015209305587642451,
#   'Consistency in the methods of teaching across modules,'),
#  (0.001519973700491218, 'More meetings to stay motivated.'),
#  (0.0015129808984791322, 'I regret losing such an interesting experience.'),
#  (0.0015099231656043254, 'More strict times to motivate me more'),
#  (0.0015099018894653082, 'Forcing people to have their cameras on!'),
#  (0.0015080358818189887, 'More compulsory homework to make me attend'),
#  (0.0015070065858089786, 'More live sessions or recorded content'),
#  (0.001505824475970963, 'More engaged/active learning'),
#  (0.0015054453629076367, 'Smaller group classes.'),
#  (0.001504709216569041, 'Nothing'),
#  (0.0015047092165690408, 'Nothing'),
#  (0.0015047092165690402, 'Nothing.'),
#  (0.0015047092165690395, 'Nothing'),
#  (0.001504709216569039, 'Nothing'),
#  (0.0015039683053765364, 'More face to face virtual contact'),
#  (0.001500373389477844, 'More interaction to help with understanding'),
#  (0.001497462709525073,
#   'Have more flexibility for students in different timezones.'),
#  (0.001492502319233953,
#   "More learning material when we didn't have the class in uni."),
#  (0.0014922229481785466, 'More quizzes to keep me engaged'),
#  (0.0014921620969482407,
#   'The duration, because it is difficult for me to stare at the screen for nearly 2 hours consecutively'),
#  (0.0014876282680176542, 'The chat should have an easier access'),
#  (0.0014816368665104438, 'Having online lectures for all units'),
#  (0.001479664052542936, 'Make them compulsory'),
#  (0.001473856701280377,
#   'More ability to discuss the topics with the lecturer'),
#  (0.0014736565597505856, 'More engagement with students'),
#  (0.0014683506406808554, 'More assignments than on the spot questions'),
#  (0.0014679535880223508, 'The awkward silence when questions are asked'),
#  (0.0014661075745728053, 'More opportunity for interaction'),
#  (0.001465465482447235, 'More interactive learning opportunities'),
#  (0.0014612287992309648, 'The quality of teaching'),
#  (0.0014605586130416852, 'That is the main problem'),
#  (0.001459064532222861, 'more live forums instead of just chatrooms'),
#  (0.001458463498860689, 'No use of recorded lectures, or YouTube videos.'),
#  (0.0014576812960213979, 'As they get repetitive.'),
#  (0.0014562384589629535, 'I wish they were more engaging'),
#  (0.0014532143251690798, 'More interaction with other students'),
#  (0.0014487204380764025, 'Be more organised and have more prep work'),
#  (0.0014395782731899147, 'More use of quizzes or opinion polls'),
#  (0.0014384097239538351, 'Have more live sessions'),
#  (0.0014374443544994523, 'Have the classes recorded'),
#  (0.001436898286552797, 'More opportunities to dig deeper into subjects'),
#  (0.0014325512019111141, 'More flexibility w due dates'),
#  (0.0014305999744584194,
#   'More consistent uploads as there has been a lack of communication'),
#  (0.0014262561141286396, 'More frequent classes'),
#  (0.0014259989743862494, 'Making attendance compulsory'),
#  (0.0014244944954604486,
#   'The classes should be as regular as during a normal semester'),
#  (0.0014198360191208827, 'More serious and more pressure to motivate me'),
#  (0.001412658828654184, 'live classes not prerecorded'),
#  (0.0014108711604437672, 'Add more detail to lectures slides'),
#  (0.001404305289865256, 'I would adjust the grading requirements.'),
#  (0.0014041811686177157, 'More live lectures'),
#  (0.0014041811686177157, 'More live lectures'),
#  (0.0014041811686177157, 'Having more live lectures.'),
#  (0.0013929831585580673, 'Smaller groups'),
#  (0.001392983158558067, 'Smaller groups'),
#  (0.0013929831585580668, 'More in smaller groups'),
#  (0.0013893172310912025, 'More interactive classes'),
#  (0.0013888312620747596, 'More interaction and discussion with classmates'),
#  (0.0013881538658525934, 'I have 8 hours of zoom some days'),
#  (0.0013850697340492312, 'More forced engagement'),
#  (0.0013844988316235292,
#   'More interaction between the students and the professor'),
#  (0.0013795652069543058, 'As of now it’s far too mundane.'),
#  (0.0013776810118533737, 'More love lectures'),
#  (0.0013767139539671222, 'More effective assessment methods'),
#  (0.0013766287157631586, 'Greater structure'),
#  (0.001376374987004572, 'Cant think of anything'),
#  (0.0013752762361893482, "They shouldn't be live."),
#  (0.0013752762361893482, 'Have them live'),
#  (0.0013731771775317115, 'Not have 2 hour videos.'),
#  (0.0013721199125660759, 'Interaction between students and professors'),
#  (0.001364257601404732, 'More live lectures, for the interactivity'),
#  (0.0013408262496788868, 'The due dates'),
#  (0.0013312688656309164, 'More consistency throughout the modules'),
#  (0.0013290930106115181, 'I don’t have online classes in Uni.'),
#  (0.0013269299468794923, 'More exam based'),
#  (0.0013249571646845252, 'have them be the same quality as before'),
#  (0.0013104020160867305, 'Shorter but more classes'),
#  (0.0012999706545792776, 'Smaller class sizes.'),
#  (0.0012999706545792776, 'Smaller class sizes'),
#  (0.0012924013112435495, 'Record the sessions'),
#  (0.00129113928646414, 'More interactive content'),
#  (0.001290741930154064,
#   'If the lecturers all uploaded useful content as only few of them have'),
#  (0.001281097703150673, 'Then not being online.'),
#  (0.0012679098617066832, 'More interaction from lecturers out of class'),
#  (0.0012673561578793217, 'Not have to use zoom'),
#  (0.0012568411051300096, 'More problem solving'),
#  (0.0012176710334639055, 'more interactions between students and lecturers'),
#  (0.00121713885524592, 'Awkward conversation'),
#  (0.0012110772479446345, 'it wasn’t worth the 18,000 per semester'),
#  (0.0011999096273619385, 'More recorded lectures'),
#  (0.0011739560707137446, 'The teacher’s comitment in some modules.'),
#  (0.0011478615099465186, 'Clearer instruction'),
#  (0.0011327645021805975, 'More in class quizzes'),
#  (0.0011237808110383372, 'More frequent!!'),
#  (0.0010835003676881133, 'more feedback from the instructors'),
#  (0.001081979125431716, 'More interaction'),
#  (0.0010819791254317159, 'More interaction'),
#  (0.0010819791254317159, 'More interaction'),
#  (0.0010819791254317154, 'more interaction'),
#  (0.001081979125431715, 'More interaction'),
#  (0.0010819791254317148, 'More interaction'),
#  (0.0010804367278751913, 'My motivation.'),
#  (0.0010729872331503832, 'More engagement'),
#  (0.0010694962686224737,
#   'It should be more interactive and not only prerecorded lectures'),
#  (0.0010557251844312459, 'I’d have them be more interactive.'),
#  (0.0010557251844312456, 'More interactive'),
#  (0.0010557251844312456, 'For them to be more interactive'),
#  (0.0010557251844312456, 'All be more interactive'),
#  (0.0010557251844312454, 'more interactive'),
#  (0.001055725184431245, 'More interactive'),
#  (0.0010128789290890852, 'More debates'),
#  (0.0010051396398807382, 'Mire questions'),
#  (0.0009929644584538407, 'The length'),
#  (0.0009923361474398096, 'They just aren’t the same as lectures.'),
#  (0.0009759902282336194, 'Delivery.'),
#  (0.0009648007009518568, 'More interaction with lecturers'),
#  (0.0008253855591699113, 'Consistency.'),
#  (0.0008199974700862317, 'The timetable.'),
#  (0.0007619490488178729, 'Unsure'),
#  (0.0007057357981851649, 'N/a'),
#  (0.0007057357981851649, 'N/A'),
#  (0.0006636765177069591, 'Whiteboard, animations, graphics etc.).'),
#  (0.0006124537097127685, 'Have it be more cohesive.'),
#  (0.0005033695728180704, 'FAQ on brightspace for each module'),
#  (0.0002421503887102761, ':('),
#  (0.0002421503887102761, '...'),
#  (0.0002421503887102761, '-'),
#  (0.00021088762109977444, 'Timings.')]

# %%
# pd.Series(result).to_csv('remote_changes_theme')
